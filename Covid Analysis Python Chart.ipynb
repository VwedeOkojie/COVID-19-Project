# %% [markdown]
# ## Total Covid Cases Vs Total Deaths

# %%
# Out:
# Index(['Canada', '2020-01-26 00:00:00.000', '1', 'NULL', 'NULL.1'], dtype='object')

# %% [markdown]
# ## Top 10 Countries with the Highest Infection Rate Compared to Population

# %%
# Out:
# Index(['Andorra', '77265', '13232', '17.1254772536077'], dtype='object')

# %% [markdown]
# ## Continent with the Highest Death Rate per Population

# %%
# Out:
# Index(['North America', '576232'], dtype='object')

# %% [markdown]
# ## Top 10 Countries with the Highest Death Rate Compared to Population

# %%
# Out:
# Index(['United States', '576232'], dtype='object')

# %% [markdown]
# ## Total Cases vs Total Deaths

# %%
# Out:
# Dataframe columns and types:
#  0      int64
# 1      int64
# 2    float64
# dtype: object
# Dataframe head:
#             0        1         2
# 0  150574977  3180206  2.112041
# Total Cases: 150574977
# Total Deaths: 3180206
# Death Percentage: 2.11204149810363

# %% [markdown]
# ## Average Pecentage of Population Vaccinated Over Time

# %%
# Out:
# Columns in dataset: Index(['Asia', 'Afghanistan', '2020-02-24 00:00:00.000', '38928341', 'NULL',
#        'NULL.1'],
#       dtype='object')

# %% [markdown]
# ## Average Percentage of People Vaccinated Over Time

# %%
# Out:
# Percentage of Population Vaccinated:
#    Asia  Afghanistan  2020-02-24 00:00:00.000    38928341  NULL  NULL.1
# 0  Asia  Afghanistan  2020-02-25 00:00:00.000  38928341.0   NaN     NaN
# 1  Asia  Afghanistan  2020-02-26 00:00:00.000  38928341.0   NaN     NaN
# 2  Asia  Afghanistan  2020-02-27 00:00:00.000  38928341.0   NaN     NaN
# 3  Asia  Afghanistan  2020-02-28 00:00:00.000  38928341.0   NaN     NaN
# 4  Asia  Afghanistan  2020-02-29 00:00:00.000  38928341.0   NaN     NaN
#
# Renamed Columns:
#   Continent     Location       Date  Population  New_vaccinations  \
# 0      Asia  Afghanistan 2020-02-25  38928341.0               NaN
# 1      Asia  Afghanistan 2020-02-26  38928341.0               NaN
# 2      Asia  Afghanistan 2020-02-27  38928341.0               NaN
# 3      Asia  Afghanistan 2020-02-28  38928341.0               NaN
# 4      Asia  Afghanistan 2020-02-29  38928341.0               NaN
#
#    PercentageOfVaccinated
# 0                     NaN
# ...
